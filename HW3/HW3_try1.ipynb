# %% [markdown]
# ### 網路爬蟲

# %% [markdown]
# #### 本來想試著使用爬蟲將BWF一年中所有賽事名稱抓取出來，但後來發現該網站的撰寫方式，好像無法符合我想達成的效果。

# %% [markdown]
# > 參考網站：
# >
# > [BWF官網](https://bwfbadminton.com/calendar/)
# >
# > [網路爬蟲基本教學](https://www.youtube.com/watch?v=9Z9xKWfNo7k&t=1s)
# >
# > [python save dataframe to csv](https://stackoverflow.com/questions/16923281/writing-a-pandas-dataframe-to-csv-file)
# >
# > [python save dictionary to JSON](https://www.geeksforgeeks.org/how-to-convert-python-dictionary-to-json/)
# >
# > [了解urllib套件](https://ithelp.ithome.com.tw/articles/10185864)
# >
# > [爬蟲實例](https://blog.jiatool.com/posts/house591_spider/)

# %%
#抓取 BWF 網頁原始碼 (HTML)
import urllib.request as req
url = "https://bwfbadminton.com/calendar/"
with req.urlopen(url) as response:
    data = response.read().decode("utf-8")
print(data)
#建立一個 Request 物件，附加 Request Headers 的資訊
request = req.Request(url,headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"
})
with req.urlopen(url) as response:
    data = response.read().decode("utf-8")
#print(data)
#解析原始碼，取得賽事名稱
import bs4 #beautifulsoup4
root = bs4.BeautifulSoup(data,"html.parser")
print(root.title.string)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# ...

# %% [markdown]
# 從 content-type 的部分可看出網站編碼為 utf-8
# ![image.png](attachment:image.png)

# %%
#建立一個 Request 物件，附加 Request Headers 的資訊
request = req.Request(url,headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"
})
with req.urlopen(url) as response:
    data = response.read().decode("utf-8")
print(data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       1 #建立一個 Request 物件，附加 Request Headers 的資訊
#       2 request = req.Request(url,headers = {
#       3     "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"
#       4 })
# ----> 5 with req.urlopen(url) as response:
#       6     data = response.read().decode("utf-8")
#       7 print(data)
#
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File C:\ProgramData\Anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
# ...

# %% [markdown]
# 有些網站為了防止過多爬蟲或不正當訪問，會設置反爬蟲，所以會出現此種(HTTP Error 403: Forbidden)error
# ![image.png](attachment:image.png)

# %%
#解析原始碼，取得賽事名稱

# %% [markdown]
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
# https://docs.python.org/zh-tw/3/library/urllib.error.html

# %% [markdown]
# ![image.png](attachment:image.png)
